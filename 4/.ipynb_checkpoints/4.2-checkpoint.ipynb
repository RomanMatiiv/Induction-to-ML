# %%
import pandas as pd
from datetime import datetime

# %%
from sklearn.decomposition import PCA
from numpy import corrcoef

# %%
data=pd.read_csv("close_prices.csv")
index=pd.read_csv("djia_index.csv")

# %%
data.date=[datetime.strptime(x,"%Y-%m-%d") for x in data.date.values]

# %%
data=data.iloc[0:,1:]

# %%
data.head()
# Out:
#          AXP          BA        CAT       CSCO         CVX         DD  \
# 0  76.440002  117.510002  85.029999  24.270000  125.519997  59.409999
# 1  76.070000  119.000000  85.110001  24.139999  124.489998  59.319997
# 2  75.989998  118.510002  84.500000  24.430000  124.070000  59.319997
# 3  76.320000  119.379997  84.199997  23.770000  123.489998  59.509996
# 4  75.889999  118.739998  83.800003  23.330000  122.639999  59.009995
#
#          DIS         GE          GS         HD    ...            PFE  \
# 0  64.750000  24.280001  165.250000  75.910004    ...      28.799999
# 1  64.320000  24.320000  162.970001  76.040001    ...      28.709999
# 2  64.449997  24.230000  162.309998  75.519997    ...      28.490000
# 3  65.239998  24.250000  162.289993  76.070000    ...      28.520000
# 4  65.190002  24.049999  159.850006  75.959999    ...      28.879999
#
#           PG          T        TRV        UNH         UTX           V  \
# ...

# %%
pca=PCA(n_components=10)

# %%
pca.fit(X=data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
sum=0
for x in pca.explained_variance_ratio_:
    print x
    sum+=x
    print sum
    print
# Out:
# 0.738971182715
# 0.738971182715
#
# 0.110071690099
# 0.849042872814
#
# 0.0499508827698
# 0.898993755584
#
# 0.0287491981999
# 0.927742953784
#
# 0.0221544788796
# 0.949897432663
#
# 0.0193157665104
# 0.969213199174
#
# 0.00674853156326
# 0.975961730737
#
# 0.0061409101866
# 0.982102640924
#
# 0.00320594168568
# 0.985308582609
#
# 0.00305611030158
# 0.988364692911

# %%
with open("a1.txt","w") as f:
    f.write("4")

# %% [markdown]
# # 3 - 4

# %%
a=pca.transform(X=data)

# %%
data2=pd.DataFrame(a)

# %%
data2.head()
# Out:
#            0          1         2         3         4         5          6  \
# 0 -50.902404  17.631677  7.736021  2.596010  2.377569  4.244055  12.883088
# 1 -52.846909  19.146907  7.272546  4.618575  0.102182  3.935519  11.062930
# 2 -54.614439  19.927358  8.109958  4.920347 -0.421454  4.555335  10.119224
# 3 -52.600566  19.941571  6.948113  4.806243  0.319779  5.065505   9.849605
# 4 -52.370123  22.289064  8.410868  3.833372 -2.464882  4.359897   7.988691
#
#           7         8         9
# 0  3.556570 -5.821974 -1.726040
# 1  3.432599 -5.633181 -2.012232
# 2  4.175203 -5.388287 -2.752699
# 3  3.266579 -5.974574 -1.922746
# 4  3.452709 -5.745204 -1.875131

# %%
index=pd.read_csv("djia_index.csv")

# %%
index.head()
# Out:
#          date          ^DJI
# 0  2013-09-23  15401.379883
# 1  2013-09-24  15334.589844
# 2  2013-09-25  15273.259766
# 3  2013-09-26  15328.299805
# 4  2013-09-27  15258.240234

# %%
x=data2[0]
y=index["^DJI"]

# %%
corrcoef([x,y])
# Out:
# array([[ 1.        ,  0.90965222],
#        [ 0.90965222,  1.        ]])

# %%
with open("a2.txt","w") as f:
    f.write("{}".format(corrcoef([x,y])[0][1]))

# %% [markdown]
# # 5

# %%
compon=pd.DataFrame(pca.components_)

# %%
compon
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.016138  0.120645 -0.051661  0.050484 -0.125860  0.114090  0.233906
# 1 -0.233026  0.138102 -0.564736 -0.029421 -0.297156 -0.070072 -0.241633
# 2 -0.105902 -0.473845 -0.053749  0.007206 -0.048401 -0.066652 -0.045366
# 3 -0.326936  0.445168 -0.230866  0.055920  0.124084  0.098464  0.219909
# 4  0.075447  0.315744 -0.171772 -0.053438  0.173984 -0.085211 -0.097893
# 5 -0.147876 -0.279149  0.014168  0.010084 -0.350357  0.092711  0.293251
# 6 -0.179904 -0.393784 -0.311796  0.121400  0.357219 -0.129996 -0.270408
# 7 -0.216013 -0.031168  0.129445  0.085260  0.469641 -0.225414  0.203127
# 8  0.072390  0.154913 -0.184295 -0.092323 -0.126029 -0.130846  0.110639
# 9 -0.371273  0.213223  0.187313  0.099688 -0.133616 -0.050084  0.015771
#
#          7         8         9     ...           20        21        22  \
# 0 -0.006205  0.251227  0.288996    ...     0.023092  0.077732 -0.007206
# ...

# %%
compon.max(axis=1)
# Out:
# 0    0.579684
# 1    0.138102
# 2    0.348309
# 3    0.445168
# 4    0.671926
# 5    0.484027
# 6    0.361613
# 7    0.469641
# 8    0.354565
# 9    0.289465
# dtype: float64

# %%
with open("a3.txt","w") as f:
    f.write("V")
